# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

titanic_df = sns.load_dataset('titanic')

# %%
titanic_df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
# 결측치 데이터 셋 확인
titanic_df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
pd.DataFrame(titanic_df['deck'])
# Out:
#     deck
# 0    NaN
# 1      C
# 2    NaN
# 3      C
# 4    NaN
# ..   ...
# 886  NaN
# 887    B
# 888  NaN
# 889    C
# 890  NaN
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(titanic_df['deck']).fillna(method='ffill')
# Out:
#     deck
# 0    NaN
# 1      C
# 2      C
# 3      C
# 4      C
# ..   ...
# 886    C
# 887    B
# 888    B
# 889    C
# 890    C
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(titanic_df['deck']).fillna(method='backfill')
# Out:
#     deck
# 0      C
# 1      C
# 2      C
# 3      C
# 4      E
# ..   ...
# 886    B
# 887    B
# 888    C
# 889    C
# 890  NaN
#
# [891 rows x 1 columns]

# %%
titanic_df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic_df.shape
# Out:
# (891, 15)

# %%
titanic_df.dropna(axis=0).head(5)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
titanic_df.dropna(axis=0).shape
# Out:
# (182, 15)

# %%
titanic_df.dropna(axis=1).head(3)
# Out:
#    survived  pclass     sex  sibsp  parch     fare  class    who  adult_male  \
# 0         0       3    male      1      0   7.2500  Third    man        True
# 1         1       1  female      1      0  71.2833  First  woman       False
# 2         1       3  female      0      0   7.9250  Third  woman       False
#
#   alive  alone
# 0    no  False
# 1   yes  False
# 2   yes   True

# %%
titanic_df.dropna(axis=1).shape
# Out:
# (891, 11)

# %%
# NaN이 많은 deck column 삭제

new_titanic_df = titanic_df.drop(['deck'], axis=1)

# %%
new_titanic_df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# NaN가 있는 행 삭제

new_titanic_df = new_titanic_df.dropna(axis=0)

# %%
new_titanic_df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic_df.shape
# Out:
# (891, 15)

# %%
new_titanic_df.shape
# Out:
# (712, 14)

# %%
import numpy as np
# 로그 변환 전
plt.hist(new_titanic_df['fare'])
plt.show()

# 로그 변환 후
Log_Fare = np.log1p(new_titanic_df['fare'])
plt.hist(Log_Fare)
plt.show()

# %%
np.expand_dims(np.array(new_titanic_df['age']),0)
# Out:
# array([[22.  , 38.  , 26.  , 35.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,
#          4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 31.  , 35.  ,
#         34.  , 15.  , 28.  ,  8.  , 38.  , 19.  , 40.  , 66.  , 28.  ,
#         42.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 18.  ,
#          7.  , 21.  , 49.  , 29.  , 65.  , 21.  , 28.5 ,  5.  , 11.  ,
#         22.  , 45.  ,  4.  , 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#         21.  , 26.  , 32.  , 25.  ,  0.83, 30.  , 22.  , 29.  , 28.  ,
#         17.  , 33.  , 16.  , 23.  , 24.  , 29.  , 20.  , 46.  , 26.  ,
#         59.  , 71.  , 23.  , 34.  , 34.  , 28.  , 21.  , 33.  , 37.  ,
#         28.  , 21.  , 38.  , 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  ,
#         70.5 , 29.  , 24.  ,  2.  , 21.  , 32.5 , 32.5 , 54.  , 12.  ,
#         24.  , 45.  , 33.  , 20.  , 47.  , 29.  , 25.  , 23.  , 19.  ,
#         37.  , 16.  , 24.  , 22.  , 24.  , 19.  , 18.  , 19.  , 27.  ,
# ...

# %%
# minmax scaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(np.expand_dims(np.array(new_titanic_df['age']),1))
scaled = scaler.transform(np.expand_dims(np.array(new_titanic_df['age']),1))

# %%
plt.hist(new_titanic_df['age'])
plt.show()

plt.hist(scaled.reshape(-1))
plt.show()

# %%
# 실습 문제 : StandardScaler 적용
# fare feature에 대해 StandardScaler 적용 후 Plot 그려보기
from sklearn.preprocessing import StandardScaler
